# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
for dirname, _, filenames in os.walk('/content/drive/MyDrive'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /content/drive/MyDrive/20WH1A1290  (1).pdf
# /content/drive/MyDrive/IMG_20210513_153608.jpg
# /content/drive/MyDrive/IMG_20210513_150941 (4).jpg
# /content/drive/MyDrive/IMG_20210513_151010 (2).jpg
# /content/drive/MyDrive/IMG_20210513_150941 (3).jpg
# /content/drive/MyDrive/IMG_20210513_150941 (2).jpg
# /content/drive/MyDrive/IMG_20210513_150941 (1).jpg
# /content/drive/MyDrive/IMG_20210513_151010 (1).jpg
# /content/drive/MyDrive/IMG_20210513_151010.jpg
# /content/drive/MyDrive/IMG_20210513_150941.jpg
# /content/drive/MyDrive/I am sharing '20WH1A1290' with you
# /content/drive/MyDrive/20WH1A1290 (1).docx
# /content/drive/MyDrive/20WH1A1290.docx
# /content/drive/MyDrive/icon.png
# /content/drive/MyDrive/Untitled document.gdoc
# /content/drive/MyDrive/data_cleaning.ipynb
# /content/drive/MyDrive/Copy_of_IntroductiontoMatplotlib1 (1).ipynb
# /content/drive/MyDrive/IntroductiontoPandas1.ipynb
# /content/drive/MyDrive/IntroductiontoPandas2.ipynb
# /content/drive/MyDrive/Copy of eigen decomosition.ipynb - Colaboratory.pdf
# /content/drive/MyDrive/probability distribution 1.pdf
# /content/drive/MyDrive/20WH1A1290 _ oop's using c++_test.gjam
# /content/drive/MyDrive/20WH1A1290 .pdf
# /content/drive/MyDrive/SQL_DBMS  LAB MATERIAL.doc
# /content/drive/MyDrive/EXP  9 Storedproc_and JOINS_R18 DBMS LAB.docx
# /content/drive/MyDrive/Unit-5 Ratio Analysis problems.pdf
# /content/drive/MyDrive/Telegram - Google Chrome 2022-11-15 18-05-22.mp4
# /content/drive/MyDrive/Telegram - Google Chrome 2022-11-18 12-40-04.mp4
# /content/drive/MyDrive/Sign Up - Google Chrome 2022-12-02 19-45-13.mp4
# /content/drive/MyDrive/Exp 11.docx
# /content/drive/MyDrive/prg5.rb
# /content/drive/MyDrive/prg4.rb
# /content/drive/MyDrive/Adobe Scan 23-Mar-2023 (1).pdf
# /content/drive/MyDrive/Adobe Scan 23-Mar-2023 (2).pdf
# /content/drive/MyDrive/Adobe Scan 23-Mar-2023 (3).pdf
# /content/drive/MyDrive/Aadhaar.pdf
# /content/drive/MyDrive/20230323_221805.jpg
# /content/drive/MyDrive/Classroom/2020 - IT - B IT - B/20WH1A1290.pdf
# /content/drive/MyDrive/Classroom/2020 - IT - B IT - B/20WH1A1290 (1) (2).pdf
# /content/drive/MyDrive/Classroom/2020 - IT - B IT - B/20WH1A1290 (2).pdf
# /content/drive/MyDrive/Classroom/2020 - IT - B IT - B/20WH1A1290 CH.PRANATHI - Pre-Final exam on March 30 2021 (2).gdoc
# /content/drive/MyDrive/Classroom/2020 - IT - B IT - B/20WH1A1290 CH.PRANATHI - Pre-Final exam on March 30 2021 (1).gdoc
# /content/drive/MyDrive/Classroom/2020 - IT - B IT - B/20WH1A1290 CH.PRANATHI - Pre-Final exam on March 30 2021.gdoc
# /content/drive/MyDrive/Classroom/I B.Tech Engineering graphics/IMG_20210513_150941.jpg
# /content/drive/MyDrive/Classroom/I B.Tech Engineering graphics/IMG_20210513_151010.jpg
# /content/drive/MyDrive/Classroom/I B.Tech Engineering graphics/IMG_20210513_153608.jpg
# /content/drive/MyDrive/Classroom/I B.Tech Engineering graphics/IMG_20210528_104225.jpg
# /content/drive/MyDrive/Classroom/I B.Tech Engineering graphics/IMG_20210528_104301.jpg
# /content/drive/MyDrive/Classroom/I B.Tech Engineering graphics/IMG_20210603_082827.jpg
# /content/drive/MyDrive/Classroom/I B.Tech Engineering graphics/IMG_20210615_111959.jpg
# /content/drive/MyDrive/Classroom/I B.Tech Engineering graphics/IMG_20210615_112016.jpg
# /content/drive/MyDrive/Classroom/I B.Tech Engineering graphics/IMG_20210715_142456.jpg
# /content/drive/MyDrive/Classroom/I B.Tech Engineering graphics/IMG_20210717_144113.jpg
# /content/drive/MyDrive/Classroom/I B.Tech Engineering graphics/IMG_20210717_144126.jpg
# /content/drive/MyDrive/Classroom/I B.Tech Engineering graphics/IMG_20210724_122000.jpg
# /content/drive/MyDrive/Classroom/I B.Tech Engineering graphics/IMG_20210724_122047.jpg
# /content/drive/MyDrive/Classroom/I B.Tech Engineering graphics/IMG_20210724_122100.jpg
# /content/drive/MyDrive/Classroom/I B.Tech Engineering graphics/IMG_20210731_152304.jpg
# /content/drive/MyDrive/Classroom/I B.Tech Engineering graphics/IMG_20210731_152354.jpg
# /content/drive/MyDrive/Classroom/I B.Tech Engineering graphics/IMG_20210731_152409.jpg
# /content/drive/MyDrive/Classroom/I B.Tech Engineering graphics/IMG-20210906-WA0029.jpg
# /content/drive/MyDrive/Classroom/I B.Tech Engineering graphics/IMG_20210906_153156.jpg
# /content/drive/MyDrive/Classroom/I B.Tech Engineering graphics/IMG_20210906_153221.jpg
# /content/drive/MyDrive/Colab Notebooks/ Image reduction..ipynb
# /content/drive/MyDrive/Colab Notebooks/ Eigen values
# /content/drive/MyDrive/Colab Notebooks/ IntroductiontoNumpy1.ipynb
# /content/drive/MyDrive/Colab Notebooks/ IntroductiontoNumpy2.ipynb
# /content/drive/MyDrive/Colab Notebooks/data_cleaning.ipynb
# /content/drive/MyDrive/Colab Notebooks/IntroductiontoMatplotlib1 (1).ipynb
# /content/drive/MyDrive/Colab Notebooks/Managing_Nulls.ipynb
# /content/drive/MyDrive/Colab Notebooks/IntroductiontoPandas2.ipynb
# /content/drive/MyDrive/Colab Notebooks/ eigen decomosition.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled0.ipynb
# /content/drive/MyDrive/Colab Notebooks/IntroductiontoPandas1.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled1.ipynb
# /content/drive/MyDrive/Colab Notebooks/ML_PROJECT.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled2.ipynb
# /content/drive/MyDrive/Colab Notebooks/sample2.ipynb
# /content/drive/MyDrive/Colab Notebooks/sample1.ipynb
# /content/drive/MyDrive/ML_project/sample_submission.csv
# /content/drive/MyDrive/ML_project/test.csv
# /content/drive/MyDrive/ML_project/train.csv

# %%
train = pd.read_csv("/content/drive/MyDrive/ML_project/train.csv")
train
# Out:
#             id cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8  ...     cont2  \
# 0            0    A    I    A    B    B   BI    A    S    Q  ...  0.759439
# 1            1    A    I    A    A    E   BI    K    W   AD  ...  0.386385
# 2            2    A    K    A    A    E   BI    A    E   BM  ...  0.343255
# 3            3    A    K    A    C    E   BI    A    Y   AD  ...  0.831147
# 4            4    A    I    G    B    E   BI    C    G    Q  ...  0.338818
# ...        ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...       ...
# 299995  499993    A    N    F    A    E   BU    A   AS    K  ...  0.662428
# 299996  499995    A    K    A    A    G   BI    A    K   AE  ...  0.821657
# 299997  499996    A    G    M    A    H   BI    C    L    F  ...  0.407037
# 299998  499997    B    H    A    D    B   BI    A   AA   AX  ...  0.808045
# 299999  499999    A    F    C    A    E   BI    C   AV    S  ...  0.775451
#
#            cont3     cont4     cont5     cont6     cont7     cont8     cont9  \
# 0       0.795549  0.681917  0.621672  0.592184  0.791921  0.815254  0.965006
# 1       0.541366  0.388982  0.357778  0.600044  0.408701  0.399353  0.927406
# 2       0.616352  0.793687  0.552877  0.352113  0.388835  0.412303  0.292696
# 3       0.807807  0.800032  0.619147  0.221789  0.897617  0.633669  0.760318
# 4       0.277308  0.610578  0.128291  0.578764  0.279167  0.351103  0.357084
# ...          ...       ...       ...       ...       ...       ...       ...
# 299995  0.671927  0.390566  0.145840  0.262767  0.514248  0.519340  0.617436
# 299996  0.620356  0.384891  0.735879  0.547731  0.726653  0.470575  0.275743
# 299997  0.232436  0.832482  0.810663  0.596939  0.308821  0.373997  0.518024
# 299998  0.630708  0.346898  0.735147  0.563488  0.609836  0.680430  0.318453
# 299999  0.848696  0.819377  0.355467  0.218153  0.968856  0.823655  0.330515
#
#           cont10 target
# 0       0.665915      0
# 1       0.493729      0
# 2       0.549452      0
# 3       0.934242      0
# 4       0.328960      1
# ...          ...    ...
# 299995  0.688007      0
# 299996  0.638939      0
# 299997  0.452144      1
# 299998  0.335822      0
# 299999  0.972569      0
#
# [300000 rows x 32 columns]

# %%
test = pd.read_csv("/content/drive/MyDrive/ML_project/test.csv")
test
# Out:
#             id cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8  ...     cont1  \
# 0            5    A    F    A    A    F   BI    A   AH   AX  ...  0.735690
# 1            6    A    H    C    A    E   AB    I    F    N  ...  0.313703
# 2            8    A    N    C    A    F   AB    A   AH   BC  ...  0.448201
# 3            9    B    L    C    A    F   BI    A    E   AX  ...  0.666092
# 4           11    A    F    A    B    F   BI    A   AH    I  ...  0.772229
# ...        ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...       ...
# 199995  499983    A    N    A    D    F   BI    A   AF   AX  ...  0.361426
# 199996  499984    B    I    A    B    E   BI    A   AS    S  ...  0.551106
# 199997  499987    A    L    D    A    H   BI    A   AN    J  ...  0.812384
# 199998  499994    A    K    A    C    F   BI    A    R   BM  ...  0.811282
# 199999  499998    A    K    A    A    E   BI    C   AO   BM  ...  0.336168
#
#            cont2     cont3     cont4     cont5     cont6     cont7     cont8  \
# 0       0.578366  0.723154  0.228037  0.356227  0.551249  0.655693  0.598331
# 1       0.928885  0.516602  0.600169  0.795224  0.248987  0.654614  0.347944
# 2       0.424876  0.344729  0.242073  0.270632  0.746740  0.335590  0.341238
# 3       0.598943  0.561971  0.806347  0.735983  0.538724  0.381566  0.481660
# 4       0.479572  0.767745  0.252454  0.354810  0.178920  0.763479  0.562491
# ...          ...       ...       ...       ...       ...       ...       ...
# 199995  0.351946  0.327670  0.205547  0.679195  0.485967  0.319130  0.520681
# 199996  0.628843  0.677765  0.624935  0.555306  0.242424  0.700829  0.531728
# 199997  0.803348  0.324762  0.665624  0.488447  0.853213  0.578641  0.811941
# 199998  0.820635  0.561449  0.797434  0.555089  0.746532  0.369986  0.438712
# 199999  0.270483  0.581868  0.218993  0.553284  0.565213  0.378355  0.547927
#
#            cont9    cont10
# 0       0.359987  0.947489
# 1       0.565520  0.388580
# 2       0.252289  0.411592
# 3       0.348514  0.325723
# 4       0.466261  0.585781
# ...          ...       ...
# 199995  0.519545  0.427119
# 199996  0.528427  0.922645
# 199997  0.537106  0.531758
# 199998  0.715524  0.381978
# 199999  0.273595  0.448016
#
# [200000 rows x 31 columns]

# %%
sample = pd.read_csv("/content/drive/MyDrive/ML_project/sample_submission.csv")
sample
# Out:
#             id  target
# 0            5     0.5
# 1            6     0.5
# 2            8     0.5
# 3            9     0.5
# 4           11     0.5
# ...        ...     ...
# 199995  499983     0.5
# 199996  499984     0.5
# 199997  499987     0.5
# 199998  499994     0.5
# 199999  499998     0.5
#
# [200000 rows x 2 columns]

# %%
target_count = train.groupby('target').target.count()
target_count
# Out:
# target
# 0    220539
# 1     79461
# Name: target, dtype: int64

# %%
percent_target = (target_count / len(train)) * 100
percent_target
# Out:
# target
# 0    73.513
# 1    26.487
# Name: target, dtype: float64

# %%
train.groupby('target').target.count().plot.bar(ylim=0)
plt.show()

# %%
target = train.target

train.drop(['target'], axis=1, inplace=True)

test_id = test.id
train_length = len(train)
samp_df = test

frames = [train, test]
combo = pd.concat(frames)
combo
# Out:
#             id cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8  ...     cont1  \
# 0            0    A    I    A    B    B   BI    A    S    Q  ...  0.855349
# 1            1    A    I    A    A    E   BI    K    W   AD  ...  0.328929
# 2            2    A    K    A    A    E   BI    A    E   BM  ...  0.322749
# 3            3    A    K    A    C    E   BI    A    Y   AD  ...  0.707663
# 4            4    A    I    G    B    E   BI    C    G    Q  ...  0.274514
# ...        ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...       ...
# 199995  499983    A    N    A    D    F   BI    A   AF   AX  ...  0.361426
# 199996  499984    B    I    A    B    E   BI    A   AS    S  ...  0.551106
# 199997  499987    A    L    D    A    H   BI    A   AN    J  ...  0.812384
# 199998  499994    A    K    A    C    F   BI    A    R   BM  ...  0.811282
# 199999  499998    A    K    A    A    E   BI    C   AO   BM  ...  0.336168
#
#            cont2     cont3     cont4     cont5     cont6     cont7     cont8  \
# 0       0.759439  0.795549  0.681917  0.621672  0.592184  0.791921  0.815254
# 1       0.386385  0.541366  0.388982  0.357778  0.600044  0.408701  0.399353
# 2       0.343255  0.616352  0.793687  0.552877  0.352113  0.388835  0.412303
# 3       0.831147  0.807807  0.800032  0.619147  0.221789  0.897617  0.633669
# 4       0.338818  0.277308  0.610578  0.128291  0.578764  0.279167  0.351103
# ...          ...       ...       ...       ...       ...       ...       ...
# 199995  0.351946  0.327670  0.205547  0.679195  0.485967  0.319130  0.520681
# 199996  0.628843  0.677765  0.624935  0.555306  0.242424  0.700829  0.531728
# 199997  0.803348  0.324762  0.665624  0.488447  0.853213  0.578641  0.811941
# 199998  0.820635  0.561449  0.797434  0.555089  0.746532  0.369986  0.438712
# 199999  0.270483  0.581868  0.218993  0.553284  0.565213  0.378355  0.547927
#
#            cont9    cont10
# 0       0.965006  0.665915
# 1       0.927406  0.493729
# 2       0.292696  0.549452
# 3       0.760318  0.934242
# 4       0.357084  0.328960
# ...          ...       ...
# 199995  0.519545  0.427119
# 199996  0.528427  0.922645
# 199997  0.537106  0.531758
# 199998  0.715524  0.381978
# 199999  0.273595  0.448016
#
# [500000 rows x 31 columns]

# %%
combo.drop(['id'], axis=1, inplace=True)
combo
# Out:
#        cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont1  \
# 0         A    I    A    B    B   BI    A    S    Q    A  ...  0.855349
# 1         A    I    A    A    E   BI    K    W   AD    F  ...  0.328929
# 2         A    K    A    A    E   BI    A    E   BM    L  ...  0.322749
# 3         A    K    A    C    E   BI    A    Y   AD    F  ...  0.707663
# 4         A    I    G    B    E   BI    C    G    Q    A  ...  0.274514
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...       ...
# 199995    A    N    A    D    F   BI    A   AF   AX    A  ...  0.361426
# 199996    B    I    A    B    E   BI    A   AS    S    E  ...  0.551106
# 199997    A    L    D    A    H   BI    A   AN    J    A  ...  0.812384
# 199998    A    K    A    C    F   BI    A    R   BM    A  ...  0.811282
# 199999    A    K    A    A    E   BI    C   AO   BM    I  ...  0.336168
#
#            cont2     cont3     cont4     cont5     cont6     cont7     cont8  \
# 0       0.759439  0.795549  0.681917  0.621672  0.592184  0.791921  0.815254
# 1       0.386385  0.541366  0.388982  0.357778  0.600044  0.408701  0.399353
# 2       0.343255  0.616352  0.793687  0.552877  0.352113  0.388835  0.412303
# 3       0.831147  0.807807  0.800032  0.619147  0.221789  0.897617  0.633669
# 4       0.338818  0.277308  0.610578  0.128291  0.578764  0.279167  0.351103
# ...          ...       ...       ...       ...       ...       ...       ...
# 199995  0.351946  0.327670  0.205547  0.679195  0.485967  0.319130  0.520681
# 199996  0.628843  0.677765  0.624935  0.555306  0.242424  0.700829  0.531728
# 199997  0.803348  0.324762  0.665624  0.488447  0.853213  0.578641  0.811941
# 199998  0.820635  0.561449  0.797434  0.555089  0.746532  0.369986  0.438712
# 199999  0.270483  0.581868  0.218993  0.553284  0.565213  0.378355  0.547927
#
#            cont9    cont10
# 0       0.965006  0.665915
# 1       0.927406  0.493729
# 2       0.292696  0.549452
# 3       0.760318  0.934242
# 4       0.357084  0.328960
# ...          ...       ...
# 199995  0.519545  0.427119
# 199996  0.528427  0.922645
# 199997  0.537106  0.531758
# 199998  0.715524  0.381978
# 199999  0.273595  0.448016
#
# [500000 rows x 30 columns]

# %%
combo.isnull().sum()
# Out:
# cat0      0
# cat1      0
# cat2      0
# cat3      0
# cat4      0
# cat5      0
# cat6      0
# cat7      0
# cat8      0
# cat9      0
# cat10     0
# cat11     0
# cat12     0
# cat13     0
# cat14     0
# cat15     0
# cat16     0
# cat17     0
# cat18     0
# cont0     0
# cont1     0
# cont2     0
# cont3     0
# cont4     0
# cont5     0
# cont6     0
# cont7     0
# cont8     0
# cont9     0
# cont10    0
# dtype: int64

# %%
corrmat = combo.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
combo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 0 to 199999
# Data columns (total 30 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   cat0    500000 non-null  object
#  1   cat1    500000 non-null  object
#  2   cat2    500000 non-null  object
#  3   cat3    500000 non-null  object
#  4   cat4    500000 non-null  object
#  5   cat5    500000 non-null  object
#  6   cat6    500000 non-null  object
#  7   cat7    500000 non-null  object
#  8   cat8    500000 non-null  object
#  9   cat9    500000 non-null  object
#  10  cat10   500000 non-null  object
#  11  cat11   500000 non-null  object
#  12  cat12   500000 non-null  object
#  13  cat13   500000 non-null  object
#  14  cat14   500000 non-null  object
#  15  cat15   500000 non-null  object
#  16  cat16   500000 non-null  object
#  17  cat17   500000 non-null  object
#  18  cat18   500000 non-null  object
#  19  cont0   500000 non-null  float64
#  20  cont1   500000 non-null  float64
#  21  cont2   500000 non-null  float64
#  22  cont3   500000 non-null  float64
#  23  cont4   500000 non-null  float64
#  24  cont5   500000 non-null  float64
#  25  cont6   500000 non-null  float64
#  26  cont7   500000 non-null  float64
#  27  cont8   500000 non-null  float64
#  28  cont9   500000 non-null  float64
#  29  cont10  500000 non-null  float64
# dtypes: float64(11), object(19)
# memory usage: 118.3+ MB

# %%
combo.describe()
# Out:
#                cont0          cont1          cont2          cont3  \
# count  500000.000000  500000.000000  500000.000000  500000.000000
# mean        0.505004       0.494028       0.516549       0.474655
# std         0.207040       0.212900       0.214811       0.216750
# min        -0.049562       0.084480       0.094493      -0.045316
# 25%         0.344881       0.317528       0.326111       0.292455
# 50%         0.479646       0.463183       0.471095       0.389550
# 75%         0.638083       0.693951       0.704678       0.645278
# max         1.006825       1.011597       1.016600       0.965609
#
#                cont4          cont5          cont6          cont7  \
# count  500000.000000  500000.000000  500000.000000  500000.000000
# mean        0.504817       0.501827       0.487863       0.502117
# std         0.227364       0.241296       0.211335       0.203615
# min         0.168071      -0.036379      -0.005648       0.090901
# 25%         0.279346       0.276002       0.323335       0.353192
# 50%         0.480037       0.554752       0.517779       0.435724
# 75%         0.725551       0.735190       0.608117       0.643630
# max         0.867198       0.853022       0.966553       1.035818
#
#                cont8          cont9         cont10
# count  500000.000000  500000.000000  500000.000000
# mean        0.488177       0.469623       0.508528
# std         0.178987       0.194709       0.203606
# min         0.013554       0.214866       0.097789
# 25%         0.359006       0.309916       0.368589
# 50%         0.411067       0.407304       0.446577
# 75%         0.612634       0.587243       0.582422
# max         1.055885       1.007189       1.011331

# %%
from sklearn import preprocessing
from sklearn.preprocessing import OrdinalEncoder

enc = OrdinalEncoder()

combo.cat0 = enc.fit_transform(combo.cat0.values.reshape(-1,1))
combo.cat1 = enc.fit_transform(combo.cat1.values.reshape(-1,1))
combo.cat2 = enc.fit_transform(combo.cat2.values.reshape(-1,1))
combo.cat3 = enc.fit_transform(combo.cat3.values.reshape(-1,1))
combo.cat4 = enc.fit_transform(combo.cat4.values.reshape(-1,1))
combo.cat5 = enc.fit_transform(combo.cat5.values.reshape(-1,1))
combo.cat6 = enc.fit_transform(combo.cat6.values.reshape(-1,1))
combo.cat7 = enc.fit_transform(combo.cat7.values.reshape(-1,1))
combo.cat8 = enc.fit_transform(combo.cat8.values.reshape(-1,1))
combo.cat9 = enc.fit_transform(combo.cat9.values.reshape(-1,1))
combo.cat10 = enc.fit_transform(combo.cat10.values.reshape(-1,1))
combo.cat11 = enc.fit_transform(combo.cat11.values.reshape(-1,1))
combo.cat12 = enc.fit_transform(combo.cat12.values.reshape(-1,1))
combo.cat13 = enc.fit_transform(combo.cat13.values.reshape(-1,1))
combo.cat14 = enc.fit_transform(combo.cat14.values.reshape(-1,1))
combo.cat15 = enc.fit_transform(combo.cat15.values.reshape(-1,1))
combo.cat16 = enc.fit_transform(combo.cat16.values.reshape(-1,1))
combo.cat17 = enc.fit_transform(combo.cat17.values.reshape(-1,1))
combo.cat18 = enc.fit_transform(combo.cat18.values.reshape(-1,1))
combo
# Out:
#         cat0  cat1  cat2  cat3  cat4  cat5  cat6  cat7  cat8  cat9  ...  \
# 0        0.0   8.0   0.0   1.0   1.0  33.0   0.0  44.0  54.0   0.0  ...
# 1        0.0   8.0   0.0   0.0   4.0  33.0   8.0  48.0   3.0   5.0  ...
# 2        0.0  10.0   0.0   0.0   4.0  33.0   0.0  30.0  38.0   9.0  ...
# 3        0.0  10.0   0.0   2.0   4.0  33.0   0.0  50.0   3.0   5.0  ...
# 4        0.0   8.0   6.0   1.0   4.0  33.0   2.0  32.0  54.0   0.0  ...
# ...      ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 199995   0.0  13.0   0.0   3.0   5.0  33.0   0.0   6.0  23.0   0.0  ...
# 199996   1.0   8.0   0.0   1.0   4.0  33.0   0.0  19.0  55.0   4.0  ...
# 199997   0.0  11.0   3.0   0.0   7.0  33.0   0.0  14.0  47.0   0.0  ...
# 199998   0.0  10.0   0.0   2.0   5.0  33.0   0.0  43.0  38.0   0.0  ...
# 199999   0.0  10.0   0.0   0.0   4.0  33.0   2.0  15.0  38.0   7.0  ...
#
#            cont1     cont2     cont3     cont4     cont5     cont6     cont7  \
# 0       0.855349  0.759439  0.795549  0.681917  0.621672  0.592184  0.791921
# 1       0.328929  0.386385  0.541366  0.388982  0.357778  0.600044  0.408701
# 2       0.322749  0.343255  0.616352  0.793687  0.552877  0.352113  0.388835
# 3       0.707663  0.831147  0.807807  0.800032  0.619147  0.221789  0.897617
# 4       0.274514  0.338818  0.277308  0.610578  0.128291  0.578764  0.279167
# ...          ...       ...       ...       ...       ...       ...       ...
# 199995  0.361426  0.351946  0.327670  0.205547  0.679195  0.485967  0.319130
# 199996  0.551106  0.628843  0.677765  0.624935  0.555306  0.242424  0.700829
# 199997  0.812384  0.803348  0.324762  0.665624  0.488447  0.853213  0.578641
# 199998  0.811282  0.820635  0.561449  0.797434  0.555089  0.746532  0.369986
# 199999  0.336168  0.270483  0.581868  0.218993  0.553284  0.565213  0.378355
#
#            cont8     cont9    cont10
# 0       0.815254  0.965006  0.665915
# 1       0.399353  0.927406  0.493729
# 2       0.412303  0.292696  0.549452
# 3       0.633669  0.760318  0.934242
# 4       0.351103  0.357084  0.328960
# ...          ...       ...       ...
# 199995  0.520681  0.519545  0.427119
# 199996  0.531728  0.528427  0.922645
# 199997  0.811941  0.537106  0.531758
# 199998  0.438712  0.715524  0.381978
# 199999  0.547927  0.273595  0.448016
#
# [500000 rows x 30 columns]

# %%
combo = (combo - combo.min()) / (combo.max() - combo.min())
combo
# Out:
#         cat0      cat1      cat2      cat3      cat4     cat5      cat6  cat7  \
# 0        0.0  0.571429  0.000000  0.083333  0.052632  0.39759  0.000000  0.88
# 1        0.0  0.571429  0.000000  0.000000  0.210526  0.39759  0.533333  0.96
# 2        0.0  0.714286  0.000000  0.000000  0.210526  0.39759  0.000000  0.60
# 3        0.0  0.714286  0.000000  0.166667  0.210526  0.39759  0.000000  1.00
# 4        0.0  0.571429  0.333333  0.083333  0.210526  0.39759  0.133333  0.64
# ...      ...       ...       ...       ...       ...      ...       ...   ...
# 199995   0.0  0.928571  0.000000  0.250000  0.263158  0.39759  0.000000  0.12
# 199996   1.0  0.571429  0.000000  0.083333  0.210526  0.39759  0.000000  0.38
# 199997   0.0  0.785714  0.166667  0.000000  0.368421  0.39759  0.000000  0.28
# 199998   0.0  0.714286  0.000000  0.166667  0.263158  0.39759  0.000000  0.86
# 199999   0.0  0.714286  0.000000  0.000000  0.210526  0.39759  0.133333  0.30
#
#             cat8      cat9  ...     cont1     cont2     cont3     cont4  \
# 0       0.900000  0.000000  ...  0.831469  0.721115  0.831778  0.734982
# 1       0.050000  0.277778  ...  0.263666  0.316548  0.580342  0.315982
# 2       0.633333  0.500000  ...  0.257000  0.269775  0.654517  0.894852
# 3       0.050000  0.277778  ...  0.672173  0.798882  0.843903  0.903929
# 4       0.900000  0.000000  ...  0.204973  0.264963  0.319137  0.632942
# ...          ...       ...  ...       ...       ...       ...       ...
# 199995  0.383333  0.000000  ...  0.298717  0.279200  0.368955  0.053604
# 199996  0.916667  0.222222  ...  0.503309  0.579488  0.715267  0.653478
# 199997  0.783333  0.000000  ...  0.785127  0.768734  0.366078  0.711677
# 199998  0.633333  0.000000  ...  0.783937  0.787481  0.600207  0.900212
# 199999  0.633333  0.388889  ...  0.271474  0.190856  0.620406  0.072836
#
#            cont5     cont6     cont7     cont8     cont9    cont10
# 0       0.739881  0.614927  0.741885  0.769141  0.946761  0.621894
# 1       0.443172  0.623011  0.336326  0.370131  0.899305  0.433412
# 2       0.662531  0.367991  0.315301  0.382555  0.098230  0.494409
# 3       0.737043  0.233940  0.853743  0.594931  0.688422  0.915616
# 4       0.185147  0.601123  0.199241  0.323840  0.179495  0.253049
# ...          ...       ...       ...       ...       ...       ...
# 199995  0.804557  0.505672  0.241533  0.486532  0.384539  0.360498
# 199996  0.665263  0.255165  0.645483  0.497130  0.395749  0.902921
# 199997  0.590090  0.883419  0.516173  0.765963  0.406704  0.475040
# 199998  0.665019  0.773688  0.295353  0.407892  0.631887  0.311085
# 199999  0.662990  0.587184  0.304210  0.512671  0.074122  0.383373
#
# [500000 rows x 30 columns]

# %%
y = target
X = combo[:train_length]
X_test = combo[train_length:]

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1
#          ..
# 299995    0
# 299996    0
# 299997    1
# 299998    0
# 299999    0
# Name: target, Length: 300000, dtype: int64

# %%
X
# Out:
#         cat0      cat1      cat2      cat3      cat4      cat5      cat6  \
# 0        0.0  0.571429  0.000000  0.083333  0.052632  0.397590  0.000000
# 1        0.0  0.571429  0.000000  0.000000  0.210526  0.397590  0.533333
# 2        0.0  0.714286  0.000000  0.000000  0.210526  0.397590  0.000000
# 3        0.0  0.714286  0.000000  0.166667  0.210526  0.397590  0.000000
# 4        0.0  0.571429  0.333333  0.083333  0.210526  0.397590  0.133333
# ...      ...       ...       ...       ...       ...       ...       ...
# 299995   0.0  0.928571  0.277778  0.000000  0.210526  0.542169  0.000000
# 299996   0.0  0.714286  0.000000  0.000000  0.315789  0.397590  0.000000
# 299997   0.0  0.428571  0.666667  0.000000  0.368421  0.397590  0.133333
# 299998   1.0  0.500000  0.000000  0.250000  0.052632  0.397590  0.000000
# 299999   0.0  0.357143  0.111111  0.000000  0.210526  0.397590  0.133333
#
#         cat7      cat8      cat9  ...     cont1     cont2     cont3     cont4  \
# 0       0.88  0.900000  0.000000  ...  0.831469  0.721115  0.831778  0.734982
# 1       0.96  0.050000  0.277778  ...  0.263666  0.316548  0.580342  0.315982
# 2       0.60  0.633333  0.500000  ...  0.257000  0.269775  0.654517  0.894852
# 3       1.00  0.050000  0.277778  ...  0.672173  0.798882  0.843903  0.903929
# 4       0.64  0.900000  0.000000  ...  0.204973  0.264963  0.319137  0.632942
# ...      ...       ...       ...  ...       ...       ...       ...       ...
# 299995  0.38  0.800000  0.000000  ...  0.448972  0.615910  0.709491  0.318247
# 299996  0.72  0.066667  0.222222  ...  0.761699  0.788589  0.658479  0.310129
# 299997  0.74  0.716667  0.000000  ...  0.472289  0.338945  0.274750  0.950344
# 299998  0.02  0.383333  0.000000  ...  0.785673  0.773828  0.668718  0.255786
# 299999  0.44  0.916667  0.000000  ...  0.793055  0.738480  0.884350  0.931598
#
#            cont5     cont6     cont7     cont8     cont9    cont10
# 0       0.739881  0.614927  0.741885  0.769141  0.946761  0.621894
# 1       0.443172  0.623011  0.336326  0.370131  0.899305  0.433412
# 2       0.662531  0.367991  0.315301  0.382555  0.098230  0.494409
# 3       0.737043  0.233940  0.853743  0.594931  0.688422  0.915616
# 4       0.185147  0.601123  0.199241  0.323840  0.179495  0.253049
# ...          ...       ...       ...       ...       ...       ...
# 299995  0.204879  0.276090  0.448026  0.485245  0.508088  0.646077
# 299996  0.868291  0.569202  0.672813  0.438461  0.076834  0.592365
# 299997  0.952374  0.619817  0.230623  0.345805  0.382620  0.387892
# 299998  0.867467  0.585409  0.549186  0.639793  0.130738  0.260561
# 299999  0.440574  0.230201  0.929134  0.777201  0.145962  0.957570
#
# [300000 rows x 30 columns]

# %%
X_test
# Out:
#         cat0      cat1      cat2      cat3      cat4      cat5      cat6  \
# 0        0.0  0.357143  0.000000  0.000000  0.263158  0.397590  0.000000
# 1        0.0  0.500000  0.111111  0.000000  0.210526  0.024096  0.466667
# 2        0.0  0.928571  0.111111  0.000000  0.263158  0.024096  0.000000
# 3        1.0  0.785714  0.111111  0.000000  0.263158  0.397590  0.000000
# 4        0.0  0.357143  0.000000  0.083333  0.263158  0.397590  0.000000
# ...      ...       ...       ...       ...       ...       ...       ...
# 199995   0.0  0.928571  0.000000  0.250000  0.263158  0.397590  0.000000
# 199996   1.0  0.571429  0.000000  0.083333  0.210526  0.397590  0.000000
# 199997   0.0  0.785714  0.166667  0.000000  0.368421  0.397590  0.000000
# 199998   0.0  0.714286  0.000000  0.166667  0.263158  0.397590  0.000000
# 199999   0.0  0.714286  0.000000  0.000000  0.210526  0.397590  0.133333
#
#         cat7      cat8      cat9  ...     cont1     cont2     cont3     cont4  \
# 0       0.16  0.383333  0.000000  ...  0.702403  0.524747  0.760165  0.085773
# 1       0.62  0.850000  0.000000  ...  0.247243  0.904876  0.555846  0.618054
# 2       0.16  0.466667  0.000000  ...  0.392314  0.358291  0.385829  0.105849
# 3       0.60  0.383333  0.000000  ...  0.627334  0.547062  0.600724  0.912962
# 4       0.16  0.766667  0.000000  ...  0.741815  0.417608  0.804275  0.120698
# ...      ...       ...       ...  ...       ...       ...       ...       ...
# 199995  0.12  0.383333  0.000000  ...  0.298717  0.279200  0.368955  0.053604
# 199996  0.38  0.916667  0.222222  ...  0.503309  0.579488  0.715267  0.653478
# 199997  0.28  0.783333  0.000000  ...  0.785127  0.768734  0.366078  0.711677
# 199998  0.86  0.633333  0.000000  ...  0.783937  0.787481  0.600207  0.900212
# 199999  0.30  0.633333  0.388889  ...  0.271474  0.190856  0.620406  0.072836
#
#            cont5     cont6     cont7     cont8     cont9    cont10
# 0       0.441428  0.572821  0.597716  0.561028  0.183160  0.930116
# 1       0.935014  0.261916  0.596574  0.320810  0.442565  0.318312
# 2       0.345189  0.773902  0.258953  0.314376  0.047232  0.343502
# 3       0.868408  0.559938  0.307609  0.449095  0.168679  0.249506
# 4       0.439835  0.189846  0.711785  0.526644  0.317289  0.534176
# ...          ...       ...       ...       ...       ...       ...
# 199995  0.804557  0.505672  0.241533  0.486532  0.384539  0.360498
# 199996  0.665263  0.255165  0.645483  0.497130  0.395749  0.902921
# 199997  0.590090  0.883419  0.516173  0.765963  0.406704  0.475040
# 199998  0.665019  0.773688  0.295353  0.407892  0.631887  0.311085
# 199999  0.662990  0.587184  0.304210  0.512671  0.074122  0.383373
#
# [200000 rows x 30 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split( X, y, test_size=0.1, shuffle=True, random_state=1)
X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape
# Out:
# ((270000, 30), (270000,), (30000, 30), (30000,), (200000, 30))

# %%
from sklearn.linear_model import LogisticRegression


model = LogisticRegression(C=100, class_weight='balanced', random_state=1, max_iter=10000).fit(X_train, y_train)
print(model.score(X_train, y_train))
# Out:
# 0.8059555555555555

# %%
import pandas as pd
model.fit(X_train, y_train)
pred_probs = model.predict_proba(X_test)
sub_df = pd.DataFrame({'id': samp_df['id']})
sub_df['Class_1'] = pred_probs[:, 0]
sub_df['Class_2'] = pred_probs[:, 1]
sub_df.to_csv('s_submission.csv', index=False)

# %%
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier

model = HistGradientBoostingClassifier(max_iter=50000, random_state=1).fit(X_train, y_train)
print(model.score(X_train, y_train))
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/experimental/enable_hist_gradient_boosting.py:16: UserWarning: Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
#   warnings.warn(
# 0.8566259259259259

# %%
y_pred = model.predict(X_val)
print(model.score(X_val,y_val))
# Out:
# 0.8536333333333334

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_val, y_pred)
# Out:
# array([[20624,  1494],
#        [ 2897,  4985]])

# %%
from sklearn.metrics import accuracy_score
score =accuracy_score(y_val, y_pred )

score
# Out:
# 0.8536333333333334

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot
from sklearn.metrics import roc_curve

# Compute predicted probabilities: y_pred_prob


# Generate ROC curve values: fpr, tpr, thresholds
fpr, tpr, thresholds = roc_curve(y_val, y_pred)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot
from sklearn.metrics import roc_curve

# Compute predicted probabilities: y_pred_prob


# Generate ROC curve values: fpr, tpr, thresholds
fpr, tpr, thresholds = roc_curve(y_val, y_pred)

# Plot ROC curve
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')

plt.fill_between(fpr, tpr)
plt.tight_layout()
plt.show()

# %%
predictions = model.predict(X_test)

# %%
output = pd.DataFrame({'id': test_id, 'target': predictions})
output.to_csv('submission.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!

# %%
submission = pd.read_csv("submission.csv")
submission
# Out:
#             id  target
# 0            5       0
# 1            6       0
# 2            8       0
# 3            9       0
# 4           11       0
# ...        ...     ...
# 199995  499983       1
# 199996  499984       0
# 199997  499987       1
# 199998  499994       0
# 199999  499998       0
#
# [200000 rows x 2 columns]
